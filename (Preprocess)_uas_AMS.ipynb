# %% [markdown]
# <a href="https://colab.research.google.com/github/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/blob/main/(Preprocess)_uas_AMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ADVAN Bangkit! Analisis Sentimen Publik terhadap Bangkitnya Brand Lokal Advan di Era Dominasi Brand Asing**

# %% [markdown]
# # **Final Project Analisis Media Sosial**
#
# | Nama | NIM | Kontribusi |
# | -------- | -------- |  -------- |
# | Ahmad Izza   | 11220940000006   |  Scraping, labeling, preprocessing, mencari insight, presentator  |
# | Alif Alamasyah | 11220940000028   |  Scraping, labeling, preprocessing, mencari insight, presentator   |
# | Ahmad Fauzan | 11220940000031  |  Scraping, labeling, preprocessing, mencari insight, presentator  |
# | Ibnullabib | 11210940000037   | Scraping, labeling, preprocessing, mencari insight, presentator  |

# %% [markdown]
# # **Preprocess Data**
#
# ---
#
# **Latar Belakang**
#
# Advan merupakan brand lokal yang sempat bersinar di pasar smartphone Indonesia. Namun, gempuran merek global dan isu keliru soal kebangkrutan sempat mengguncang reputasinya. Melalui inovasi besar, Advan berupaya bangkit dengan identitas baru dan inovasi.
#
# ---
#
# **Mengapa penting untuk di analisis?**
#
# - Mengukur persepsi publik sebelum & sesudah bangkitnya Advan.
# - Mengidentifikasi topik dan fitur yang paling sering dibahas (spesifikasi, harga, kamera, dll.).
# - Mengevaluasi perubahan tren sentimen publik.
# - Menyediakan insight berbasis data untuk strategi brand dan pemasaran.
#
# ---
#
# **Data**
#
#   Untuk mendukung analisis sentimen dan topik seputar persepsi publik terhadap brand Advan sebelum dan sesudah masa ‘Bangkit’ tahun 2020, digunakan data komentar dari platform YouTube sebagai sumber utama. Data dikumpulkan menggunakan YouTube Data API, yang memungkinkan pengambilan komentar publik dari berbagai video secara terstruktur dan terstandarisasi.
#
#
#
#   Data dikumpulkan dari dua periode waktu yang berbeda, yang masing-masing mewakili fase sebelum masa bangkit dan sesudah masa bangkit:
#   *   Before Bangkit (2016–2017):
#
#       Total komentar: 417 komentar
#
#       Video yang dianalisis:
#         *   [Advan i5E Full Review – Gila! Cuma 1 Jutaan](https://www.youtube.com/watch?v=zp9s8ZvyqPQ)
#         *   [Advan G1 Pro - REVIEW INDONESIA](https://www.youtube.com/watch?v=sLMD8lIzayo)
#
#   *   After Bangkit (2020-2025):
#
#         Total komentar: 13.395 komentar
#
#         Video yang dianalisis:
#         *   [Advan GX 5G AI - Official Launch Video (2024)](https://www.youtube.com/watch?v=B8z0SHWkgMU)
#         *   [Advan Skynote Launch Trailer](https://www.youtube.com/watch?v=Z27dlq3H3hM)
#         *   [Review Advan AI Book (2024)](https://www.youtube.com/watch?v=QY0rhBg5jzk)
#         *   [ADvan Tab VX Gaming Test](https://www.youtube.com/watch?v=j_kSv6J0D4k)
#         *   [Advan WorkPro Series – AI Inside](https://www.youtube.com/watch?v=npDzS9mZlXI)
#         *   [Advan #Bangkit Campaign Video](https://www.youtube.com/watch?v=BxdZm7PUIaw)
#         *   [Test Kamera Advan AI Phone](https://www.youtube.com/watch?v=bTljfq7VTQs)
#         *      [Advan 2025 Vision – Rebranding Campaign](https://www.youtube.com/watch?v=ofWSHfTYtVk)
#         *   [Official Advan Promo – AI Revolution](https://www.youtube.com/watch?v=5E4qGaWX0LU)
#
#
#   Pemilihan video dilakukan secara purposif berdasarkan popularitas dan relevansi kontennya dengan narasi brand Advan pada masing-masing periode.

# %% [markdown]
# # Load Modul yang diperlukan

# %%
# !pip install Sastrawi -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.7 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import matplotlib.pyplot as plt
import requests
import string
import openpyxl
import spacy

from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# # Load Dataset

# %%
df_before = pd.read_excel('https://github.com/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/raw/refs/heads/main/dataset_labeling/df_before.xlsx')
df_before.sample(5)
# Out:
#                          author            updated_at  like_count  \
# 136              @kunsquads4780  2017-03-02T10:26:38Z           0
# 387                 @dennygun19  2016-04-03T12:02:05Z           0
# 1                      @danzzxt  2025-07-03T07:18:37Z           0
# 173              @abdulazis9945  2017-01-17T09:25:27Z           0
# 233  @thomasstamfordraffles5255  2017-01-15T13:38:28Z           0
#
#                                                   text     video_id  public  \
# 136  bang david review advan i5c dong terus saya ta...  zp9s8ZvyqPQ    True
# 387  gileee.. system makan 10 GB ? smartphone gilee...  sLMD8lIzayo    True
# 1                                                 Jirr  zp9s8ZvyqPQ    True
# 173        bang bikin review chuwi hi10 main game bang  zp9s8ZvyqPQ    True
# 233                             not recommended to buy  zp9s8ZvyqPQ    True
#
#      sentiment
# 136          0
# 387          2
# 1            0
# 173          0
# 233          2

# %%
df_after = pd.read_excel('https://github.com/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/raw/refs/heads/main/dataset_labeling/df_after.xlsx')
df_after.sample(5)
# Out:
#                            author            updated_at  like_count  \
# 9343             @PseudoNoiseCode  2023-08-09T01:14:51Z           0
# 8975               @anjaymabar661  2023-10-21T03:18:44Z           0
# 5618                 @zulfines850  2021-07-17T05:00:39Z           0
# 12639  @KARANGTARUNATANIMULYARW01  2025-06-24T05:52:27Z           0
# 9193                    @waltzinx  2023-08-19T14:08:39Z           0
#
#                                                     text     video_id  public  \
# 9343                           After salesnya gimana ya?  BxdZm7PUIaw    True
# 8975                          Bisa make simcard ngk bng?  BxdZm7PUIaw    True
# 5618                                    Mantap reviewnya  Z27dlq3H3hM    True
# 12639                       0:19 nanti ada x2 x3 x4 x5 😅  5E4qGaWX0LU    True
# 9193   kaget bgt nemu ini kebetulan lagi nyari buat k...  BxdZm7PUIaw    True
#
#        sentiment
# 9343         0.0
# 8975         0.0
# 5618         1.0
# ...

# %% [markdown]
# # Preprocessing

# %%
# Jalankan Cell ini "HANYA" jika anda menggunakan Google Colab
# Jika di jalankan di komputer local, silahkan lihat NLPTM-02 untuk instalasinya.
import warnings; warnings.simplefilter('ignore')

try:
    import google.colab; IN_COLAB = True
    # !wget https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/taudataNlpTm.py
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/slang.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/stopwords_id.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/stopwords_en.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/kata_dasar.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/wn-ind-def.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/wn-msa-all.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/ind_SA.csv
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/all_indo_man_tag_corpus_model.crf.tagger

    # !pip install spacy python-crfsuite unidecode textblob sastrawi
    # !python -m spacy download xx
    # !python -m spacy download en_core_web_sm

    nltk.download('popular')
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")
# Out:
# --2025-07-17 14:15:39--  https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/taudataNlpTm.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14001 (14K) [text/plain]
# Saving to: ‘taudataNlpTm.py’
#
# taudataNlpTm.py     100%[===================>]  13.67K  --.-KB/s    in 0s
#
# 2025-07-17 14:15:39 (27.9 MB/s) - ‘taudataNlpTm.py’ saved [14001/14001]
#
# --2025-07-17 14:15:39--  https://raw.githubusercontent.com/taudataanalytics/taudata-Academy/d352ef3839f8b2d4da056dd67904bc38ce32f48e/data/slang.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# Download resource NLTK (hanya perlu sekali)
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger') # This one might be enough, but eng is specific
nltk.download('averaged_perceptron_tagger_eng') # Add this line to be sure
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# ...

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## df_before

# %%
df_before.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      418 non-null    object
#  1   updated_at  418 non-null    object
#  2   like_count  418 non-null    int64
#  3   text        418 non-null    object
#  4   video_id    418 non-null    object
#  5   public      418 non-null    bool
#  6   sentiment   418 non-null    int64
# dtypes: bool(1), int64(2), object(4)
# memory usage: 20.1+ KB

# %%
# Mengubah tipe data
df_before['updated_at'] = pd.to_datetime(df_before['updated_at'])
df_before['sentiment'] = df_before['sentiment'].astype('category')
df_before['text'] = df_before['text'].astype('string')

# %%
# Mengecek dataset yang kosong (null)
print(df_before.isnull().sum())
# Out:
# author        0
# updated_at    0
# like_count    0
# text          0
# video_id      0
# public        0
# sentiment     0
# dtype: int64

# %%
# Mengecek duplikasi data
print(df_before.duplicated().sum())
# Out:
# 0

# %%
# Mangambil kolom 'text' untuk text cleaning
df_before_text = df_before[['sentiment','text']]
df_before_text.sample(5)
# Out:
#     sentiment                                               text
# 176         0                               versi androidnya apa
# 379         0      bang minta link wallpappernya dong plisss 😊😊😊
# 275         2                                     #mendingxiaomi
# 261         0  bang unboxing n review Zenfone 3 Max yg pake L...
# 128         0                     bang ,,coba review advan g1 ya

# %% [markdown]
# ### Text cleaning

# %% [markdown]
# #### Menghapus slang

# %%
# !wget -N -P data/ https://raw.githubusercontent.com/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/refs/heads/main/slangs%20%26%20typos.txt
# Out:
# --2025-07-17 14:16:22--  https://raw.githubusercontent.com/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/refs/heads/main/slangs%20%26%20typos.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61996 (61K) [text/plain]
# Saving to: ‘data/slangs & typos.txt’
#
# slangs & typos.txt  100%[===================>]  60.54K  --.-KB/s    in 0.01s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-07-17 14:16:22 (4.72 MB/s) - ‘data/slangs & typos.txt’ saved [61996/61996]

# %%
# Lokasi file
slang_file = 'data/slangs & typos.txt'

# Membuat kamus slang dari file
slang_dict = {}
with open(slang_file, 'r', encoding='utf-8') as file:
    for line in file:
        if ':' in line:
            slang, standard = line.strip().split(':', 1)
            slang_dict[slang.strip()] = standard.strip()

# Pastikan sudah import word_tokenize (dari NLTK)
from nltk.tokenize import word_tokenize

# Fungsi untuk mengganti slang dengan kata baku
def normalize_slang(text):
    words = word_tokenize(text.lower())
    return ' '.join([slang_dict.get(word, word) for word in words])

# %%
# Terapkan ke kolom 'cleaned_text'
df_before_text['slang'] = df_before_text['text'].apply(normalize_slang)

# Lihat hasil
df_before_text.head()
# Out:
#   sentiment                                          text  \
# 0         0   Halo gaes David dsini, 8 tahun yang lalu 😢😢
# 1         0                                          Jirr
# 2         0  hp lama gw, skrg batrenya udh kembung wkwkwk
# 3         0                  Lah gua masih nonton 2025🎉🎉🎉
# 4         0                         Hp Android pertama gw
#
#                                                slang
# 0      halo guys david disini , 8 tahun yang lalu 😢😢
# 1                                               jirr
# 2  hp lama aku , sekarang batrenya sudah kembung ...
# 3                      lah saya masih nonton 2025🎉🎉🎉
# 4                             hp android pertama aku

# %% [markdown]
# #### Lemmatisasi, menghapus simbol, dan stopword

# %%
# preprocessing df_before_text
import taudataNlpTm as tau
from tqdm import tqdm
D = df_before_text['slang'].to_list()
stops, lemmatizer = tau.LoadStopWords(lang='id')
for i,d in tqdm(enumerate(D)):
    D[i] = tau.cleanText(d, lemma=lemmatizer, stops = stops, symbols_remove = True, min_charLen = 2, lan='id')
print(D[0])
df_before_text['normalized_text'] = D
df_before_text
# Out:
# 418it [01:16,  5.46it/s]
# halo guys david
#     sentiment                                          text  \
# 0           0   Halo gaes David dsini, 8 tahun yang lalu 😢😢
# 1           0                                          Jirr
# 2           0  hp lama gw, skrg batrenya udh kembung wkwkwk
# 3           0                  Lah gua masih nonton 2025🎉🎉🎉
# 4           0                         Hp Android pertama gw
# ..        ...                                           ...
# 413         0                                      petromax
# 414         0                                     dobe dobe
# 415         0                                    cendol gan
# 416         0                                      pertamax
# 417         0                                  Pertalite :v
#
#                                                  slang  \
# 0        halo guys david disini , 8 tahun yang lalu 😢😢
# 1                                                 jirr
# ...

# %% [markdown]
# #### Stopword

# %%
# !wget -N -P data/ https://raw.githubusercontent.com/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/refs/heads/main/stopwords_manual.txt
# Out:
# --2025-07-17 14:17:48--  https://raw.githubusercontent.com/Labibbib/Analisis-Sentimen-terhadap-Rebranding-Brand-Lokal-Advan/refs/heads/main/stopwords_manual.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9384 (9.2K) [text/plain]
# Saving to: ‘data/stopwords_manual.txt’
#
# stopwords_manual.tx 100%[===================>]   9.16K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-07-17 14:17:48 (56.5 MB/s) - ‘data/stopwords_manual.txt’ saved [9384/9384]

# %%
# Membaca file stopwords
stopword_files = ['data/stopwords_manual.txt']
id_stop = []
for stopword_file in stopword_files:
    with open(stopword_file, "r", encoding="utf-8", errors='replace') as file:
        id_stop.extend([word.strip().lower() for word in file.readlines()])


# Bersihkan stopwords (hapus spasi dan ubah ke huruf kecil)
id_stop = [word for word in id_stop if word] # remove empty strings

# %%
additional_stopwords = {'bang','petromax','pertalite','admin', 'mh', 'nya', 'iya', 'itu', 'kah', 'dan', 'ke', 'di',
                        'sih', 'coooyyyyy', 'sukak', 'syaaa', 'hehe', 'ongkos', 'ongkir',
                        'belanja', 'gratis', 'pakai', 'dengan', 'banget', 'orang', 'ini',
                        'guyss', 'z', 'kak', 'udah', 'nih', 'k', 'negara', 'dah', 'gin', 'mah', 'lebih', 'tuh',
                        'tau', 'deh', 'x', 'lg', 'kayak', 'karna', 'dpt', 'trus', 'gada', 'ka', 'manaaaaaaaaaaa',
                        'y', 'sm', 'tpi', 'wkwkwk', 'dobe', 'david', 'mas'}

id_stop.extend(additional_stopwords)  # Gabungkan stopwords tambahan

# Fungsi untuk menghapus stopwords
def remove_custom_stopwords(text):
    words = word_tokenize(text)  # Tokenisasi teks
    return ' '.join([word for word in words if word not in id_stop])

# %%
df_before_text['stopword_manual'] = df_before_text['normalized_text'].apply(remove_custom_stopwords)

# %%
df_before_text
# Out:
#     sentiment                                          text  \
# 0           0   Halo gaes David dsini, 8 tahun yang lalu 😢😢
# 1           0                                          Jirr
# 2           0  hp lama gw, skrg batrenya udh kembung wkwkwk
# 3           0                  Lah gua masih nonton 2025🎉🎉🎉
# 4           0                         Hp Android pertama gw
# ..        ...                                           ...
# 413         0                                      petromax
# 414         0                                     dobe dobe
# 415         0                                    cendol gan
# 416         0                                      pertamax
# 417         0                                  Pertalite :v
#
#                                                  slang  \
# 0        halo guys david disini , 8 tahun yang lalu 😢😢
# 1                                                 jirr
# 2    hp lama aku , sekarang batrenya sudah kembung ...
# ...

# %% [markdown]
# ## df_after

# %% [markdown]
# ### Text cleaning

# %%
df_after.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13395 entries, 0 to 13394
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      13394 non-null  object
#  1   updated_at  13395 non-null  object
#  2   like_count  13395 non-null  int64
#  3   text        13393 non-null  object
#  4   video_id    13395 non-null  object
#  5   public      13395 non-null  bool
#  6   sentiment   13394 non-null  float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 641.1+ KB

# %%
# Mengubah tipe data
df_after['updated_at'] = pd.to_datetime(df_after['updated_at'])
df_after['sentiment'] = df_after['sentiment'].astype('category')
df_after['text'] = df_after['text'].astype('string')

# %%
# Mengecek dataset yang kosong (null)
print(df_after.isnull().sum())
# Out:
# author        1
# updated_at    0
# like_count    0
# text          2
# video_id      0
# public        0
# sentiment     1
# dtype: int64

# %%
# Drop data yang terdapat null
df_after = df_after.dropna()

# %%
# Mengecek duplikasi data
print(df_after.duplicated().sum())
# Out:
# 2

# %%
# Mangambil kolom 'text' untuk text cleaning
df_after_text = df_after[['sentiment','text']]
df_after_text.sample(5)
# Out:
#       sentiment                                               text
# 4129        1.0               Setidaknya menang dari redmi 9c lah😎
# 1365        0.0   TAI DIBUAT BUKA SHOPEE AJA LANGSUNG ANGET HADEHH
# 2338        0.0                              Galaxy A22 bang David
# 4623        0.0  untuk harga segitu, lumayan sih dan minus di k...
# 12269       0.0                                  BG REVIEW POCO F7

# %% [markdown]
# #### Menghapus slang

# %%
# Terapkan ke kolom 'cleaned_text'
df_after_text['slang'] = df_after_text['text'].apply(normalize_slang)

# Lihat hasil
df_after_text.head()
# Out:
#   sentiment                                               text  \
# 0       0.0  Bisa dibeli di:
#
# - Shopee: https://invol.co/cl...
# 1       0.0  Dan sekarang harganya udah turun, gw beli 650k...
# 2       0.0                Itu tablet bisa main Roblox g bang?
# 3       0.0  Kalo gak disetup dulu dan langsung online, jad...
# 4       0.0                    bisa Split Screen bang ? thanks
#
#                                                slang
# 0  bisa dibeli di : - shopee : https : //invol.co...
# 1  dan sekarang harganya sudah turun , aku beli 6...
# 2           itu tablet bisa main roblox tidak bang ?
# 3  kalau tidak disetup dahulu dan langsung online...
# 4              bisa split screen bang ? terima kasih

# %% [markdown]
# #### Lematisasi, menghapus, simbol, dan stopword

# %%
# preprocessing df_after_text
import taudataNlpTm as tau
from tqdm import tqdm
D = df_after_text['slang'].to_list()
stops, lemmatizer = tau.LoadStopWords(lang='id')
for i,d in tqdm(enumerate(D)):
    D[i] = tau.cleanText(d, lemma=lemmatizer, stops = stops, symbols_remove = True, min_charLen = 2, lan='id')
print(D[0])
df_after_text['normalized_text'] = D
df_after_text
# Out:
# 13391it [17:40, 12.63it/s]
# beli shopee https invol co bekas review kadang jual https smarturl it shopee gghp
#       sentiment                                               text  \
# 0           0.0  Bisa dibeli di:
#
# - Shopee: https://invol.co/cl...
# 1           0.0  Dan sekarang harganya udah turun, gw beli 650k...
# 2           0.0                Itu tablet bisa main Roblox g bang?
# 3           0.0  Kalo gak disetup dulu dan langsung online, jad...
# 4           0.0                    bisa Split Screen bang ? thanks
# ...         ...                                                ...
# 13390       0.0                                               Firs
# 13391       0.0                                            Pertama
# 13392       0.0                                              Wehhh
# 13393       0.0                                           Akhirnya
# 13394       0.0                                               Halo
#
# ...

# %% [markdown]
# #### Stopword

# %%
df_after_text['stopword_manual'] = df_after_text['normalized_text'].apply(remove_custom_stopwords)

# %%
df_after_text
# Out:
#       sentiment                                               text  \
# 0           0.0  Bisa dibeli di:
#
# - Shopee: https://invol.co/cl...
# 1           0.0  Dan sekarang harganya udah turun, gw beli 650k...
# 2           0.0                Itu tablet bisa main Roblox g bang?
# 3           0.0  Kalo gak disetup dulu dan langsung online, jad...
# 4           0.0                    bisa Split Screen bang ? thanks
# ...         ...                                                ...
# 13390       0.0                                               Firs
# 13391       0.0                                            Pertama
# 13392       0.0                                              Wehhh
# 13393       0.0                                           Akhirnya
# 13394       0.0                                               Halo
#
#                                                    slang  \
# 0      bisa dibeli di : - shopee : https : //invol.co...
# ...

# %%
# --- Kode untuk Top 100 Kata dari df_stemmed ---

from collections import Counter

all_words = []

# Iterasi melalui setiap entri di kolom 'stemmed_text'
# Menggunakan .dropna() untuk menghindari error jika ada nilai NaN
# Menggunakan .astype(str) untuk mengubah semua nilai menjadi string (mengantisipasi jika ada tipe df_after_text lain)
for text_entry in df_after_text['stopword_manual'].dropna().astype(str):
    if text_entry.strip():  # Memastikan string tidak kosong setelah di-strip
        # Jika isi 'stemmed_text' adalah string kata-kata yang dipisahkan spasi
        words = text_entry.split()
        all_words.extend(words)
        # Jika isi 'stemmed_text' sudah berupa list of words, Anda bisa langsung:
        # all_words.extend(text_entry) # Namun, ini memerlukan text_entry sudah pasti list

# Hitung frekuensi setiap kata
word_counts = Counter(all_words)

# Dapatkan 100 kata paling umum
top_100_words = word_counts.most_common(100)

print("--- Top 100 kata yang sering muncul dari 'stemmed_text' ---")
if top_100_words:
    for word, count in top_100_words:
        print(f"{word}: {count}")
else:
    print("Tidak ada kata untuk dihitung (mungkin semua entri kosong atau NaN).")
print("-" * 40)
# Out:
# --- Top 100 kata yang sering muncul dari 'stemmed_text' ---
# harga: 935
# bagus: 880
# kamera: 801
# laptop: 666
# moga: 432
# saing: 371
# mantap: 366
# game: 341
# poco: 330
# bikin: 325
# tuju: 324
# cinta: 316
# murah: 309
# spesifikasi: 307
# kualitas: 304
# keren: 294
# maju: 287
# infinix: 284
# samsung: 278
# negeri: 278
# xiaomi: 262
# layar: 252
# dukung: 229
# suka: 213
# pova: 213
# tablet: 205
# video: 205
# chipset: 198
# baterai: 197
# china: 197
# tecno: 194
# redmi: 192
# android: 186
# merk: 182
# os: 182
# ram: 181
# performa: 181
# semangat: 175
# ganti: 171
# lumayan: 170
# snapdragon: 168
# kalah: 168
# smartphone: 166
# bangga: 161
# jual: 160
# tara: 159
# gila: 157
# kembang: 154
# gaming: 151
# cocok: 144
# rusak: 143
# tab: 139
# masuk: 139
# tahan: 137
# realme: 137
# unisoc: 135
# logo: 134
# awet: 132
# support: 132
# merek: 128
# update: 124
# banding: 120
# skin: 120
# axioo: 119
# kelas: 115
# mahal: 114
# umpat: 113
# cepat: 112
# barang: 111
# ...

# %%
df_before.isnull().sum()
# Out:
# author        0
# updated_at    0
# like_count    0
# text          0
# video_id      0
# public        0
# sentiment     0
# dtype: int64

# %% [markdown]
# # Menggabungkan dataset

# %%
# Menggabungkan dataset before
df_before = df_before[df_before['text'].isin(df_before_text['text'])]

# %%
df_before_cleaned = pd.concat([df_before, df_before_text['stopword_manual']], axis=1)
df_before_cleaned.sample(10)
# Out:
#                    author            updated_at  like_count  \
# 17      @dhiampermana1072  2021-04-25T16:13:14Z           0
# 45        @sincereboy8675  2018-09-29T11:26:07Z           0
# 83     @hidayatulilmi3725  2018-01-08T12:34:19Z           0
# 90        @dilefadiguyman  2017-10-29T10:44:19Z           0
# 112   @gilangrahmanda1006  2017-05-15T09:39:37Z           0
# 313  @kurniawanfaizal2721  2017-01-15T07:59:13Z          13
# 156     @andhikairyan6270  2017-01-20T05:10:34Z           0
# 44       @wahidwijaya8312  2018-11-06T01:45:42Z           0
# 291     @haditsnahera7026  2017-01-15T08:31:31Z           0
# 196           @seinza7949  2017-01-16T07:37:55Z           0
#
#                                                   text     video_id  public  \
# 17                                           2021 chek  zp9s8ZvyqPQ    True
# 45   Gw pake.. Kekurangannya yg bikin kesel.. Malwa...  zp9s8ZvyqPQ    True
# ...

# %%
# Menggabungkan dataset afterdf_after
df_after = df_after[df_after['text'].isin(df_after_text['text'])]

# %%
df_after_cleaned = pd.concat([df_after, df_after_text['stopword_manual']], axis=1)
df_after_cleaned.sample(10)
# Out:
#                           author            updated_at  like_count  \
# 1699               @rendyadi2032  2021-07-25T11:44:02Z         0.0
# 250               @AbsahalPaisal  2024-05-20T04:23:07Z         0.0
# 3291         @thekingalucard8702  2021-07-18T08:20:02Z         0.0
# 8536            @edipallasan3999  2025-03-27T20:56:27Z         0.0
# 11519               @areyarahmat  2025-06-29T13:29:18Z         0.0
# 1102   @kanggandivallantfive7555  2021-09-12T13:22:03Z         0.0
# 7324                  @rizmulmat  2021-07-17T01:07:35Z         5.0
# 11664             @lofislife4753  2025-06-26T18:03:28Z         0.0
# 12982                    @embeer  2025-06-24T04:23:53Z         0.0
# 11083             @thevector4596  2022-06-16T23:16:18Z         2.0
#
#                                                     text     video_id public  \
# 1699               Vid david aku njalok hpmu sitok ae???  Z27dlq3H3hM   True
# ...

# %% [markdown]
# # Preprocessing untuk Topic Modelling

# %%
def remove_URL(text): # Menghapus URL
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)

def remove_html(text): # Menghapus tag HTML
    html = re.compile(r'<.*?>')
    return html.sub(r'', text)

def remove_emoji(text): # Menghapus emoji
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U00002702-\U000027B0"  # Dingbats
        u"\U000024C2-\U0001F251"  # Enclosed characters
                            "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def remove_numbers (text): # Menghapus angka
    text = re.sub(r'\d+', '', text)
    return text

def remove_duplspaces (text): # Menghapus spasi berlebih
    text = re.sub(r'\s+', ' ', text)
    return text

def remove_symbols (text): # Menghapus simbol
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return text

# %% [markdown]
# ## df_before

# %%
df_before_bert = df_before[['sentiment','text']]

# %%
df_before_bert.head(5)
# Out:
#    sentiment                                          text
# 0          0   Halo gaes David dsini, 8 tahun yang lalu 😢😢
# 1          0                                          Jirr
# 2          0  hp lama gw, skrg batrenya udh kembung wkwkwk
# 3          0                  Lah gua masih nonton 2025🎉🎉🎉
# 4          0                         Hp Android pertama gw

# %%
df_before_bert['cleaned_text'] = df_before_bert['text'].apply(remove_URL)
df_before_bert['cleaned_text'] = df_before_bert['cleaned_text'].apply(remove_html)
df_before_bert['cleaned_text'] = df_before_bert['cleaned_text'].apply(remove_emoji)
df_before_bert['cleaned_text'] = df_before_bert['cleaned_text'].apply(remove_numbers)
df_before_bert['cleaned_text'] = df_before_bert['cleaned_text'].apply(remove_duplspaces)
df_before_bert['cleaned_text'] = df_before_bert['cleaned_text'].apply(remove_symbols)

# %%
df_before_bert.sample(5)
# Out:
#      sentiment                                               text  \
# 360          0                               10gb untuk sistem-_-
# 274          0  coba bandingin sama infinix hot 4 x557 (3g). h...
# 125          0                   kak baterai nya bisa di bila nya
# 51           0  Itu ios androidnya masih lolipop ya apakah uda...
# 112          0                          unboxing advan i5a bang..
#
#                                           cleaned_text
# 360                                    gb untuk sistem
# 274  coba bandingin sama infinix hot x g harganya s...
# 125                   kak baterai nya bisa di bila nya
# 51   Itu ios androidnya masih lolipop ya apakah uda...
# 112                             unboxing advan ia bang

# %% [markdown]
# ## df_after

# %%
df_after_bert = df_after[['sentiment','text']]

# %%
df_after_bert.head(5)
# Out:
#    sentiment                                               text
# 0        0.0  Bisa dibeli di:\n\n- Shopee: https://invol.co/...
# 1        0.0  Dan sekarang harganya udah turun, gw beli 650k...
# 2        0.0                Itu tablet bisa main Roblox g bang?
# 3        0.0  Kalo gak disetup dulu dan langsung online, jad...
# 4        0.0                    bisa Split Screen bang ? thanks

# %%
df_after_bert['cleaned_text'] = df_after_bert['text'].apply(remove_URL)
df_after_bert['cleaned_text'] = df_after_bert['cleaned_text'].apply(remove_html)
df_after_bert['cleaned_text'] = df_after_bert['cleaned_text'].apply(remove_emoji)
df_after_bert['cleaned_text'] = df_after_bert['cleaned_text'].apply(remove_numbers)
df_after_bert['cleaned_text'] = df_after_bert['cleaned_text'].apply(remove_duplspaces)
df_after_bert['cleaned_text'] = df_after_bert['cleaned_text'].apply(remove_symbols)

# %%
df_after_bert.sample(5)
# Out:
#        sentiment                                               text  \
# 67           0.0            0:01\nWkwkwk. Kepala bang david nongol😂
# 9903         0.0                     Akhirnya yg ditunggu² om ded 😁
# 7480         0.0                                               Okeh
# 10405        0.0                    Semoga tambah gede kayak huawei
# 1787         1.0  Kalau ini Mending Advan seri baru  daripada Xi...
#
#                                             cleaned_text
# 67                       Wkwkwk Kepala bang david nongol
# 9903                        Akhirnya yg ditunggu om ded
# 7480                                                Okeh
# 10405                    Semoga tambah gede kayak huawei
# 1787   Kalau ini Mending Advan seri baru daripada Xia...

# %% [markdown]
# # Menyimpan dataset

# %%
df_before_text.to_excel('before_cleaned.xlsx', index=False)
df_after_text.to_excel('after_cleaned.xlsx', index=False)

df_before_bert.to_excel('before_bert.xlsx', index=False)
df_after_bert.to_excel('after_bert.xlsx', index=False)
